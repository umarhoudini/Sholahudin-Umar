# %%
# STEP 1: Install library yang dibutuhkan
# Langchain_community: library untuk memanfaatkan LLM (Large Language Model)
# Replicate: library untuk akses model AI di cloud (di sini, model Granite IBM)

# !pip install langchain_community
# !pip install replicate

# %%
# STEP 2: Import library yang akan digunakan
import os
from google.colab import userdata

# Ambil token API dari Colab (pastikan kamu sudah menyimpan token di environment)
api_token = userdata.get("api_token")

# Simpan token sebagai variabel environment supaya Replicate bisa memakainya
os.environ["REPLICATE_API_TOKEN"] = api_token

# %%
# STEP 2: Import library yang akan digunakan
import os
from google.colab import userdata

# Ambil token API dari Colab (pastikan kamu sudah menyimpan token di environment)
api_token = userdata.get("api_token")

# Simpan token sebagai variabel environment supaya Replicate bisa memakainya
os.environ["REPLICATE_API_TOKEN"] = api_token

# %%
# STEP 4: Mount Google Drive supaya file CSV bisa diakses
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# STEP 5: Load dataset pengeluaran per kapita dari CSV
import pandas as pd

# Ganti path sesuai lokasi file kamu di Google Drive
file_path = "/content/drive/MyDrive/Final Project/Data Set/bps-od_17106_pengeluaran_per_kapita_disesuaikan__kabupatenkota_v1_data.csv"

# Baca CSV dengan separator koma dan encoding latin1
df = pd.read_csv(file_path, sep=",", encoding="latin1")

# Tampilkan 5 baris pertama untuk cek data
df.head()
# Out:
#    id  kode_provinsi nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  \
# 0   1             32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 1   2             32    JAWA BARAT                 3202  KABUPATEN SUKABUMI
# 2   3             32    JAWA BARAT                 3203   KABUPATEN CIANJUR
# 3   4             32    JAWA BARAT                 3204   KABUPATEN BANDUNG
# 4   5             32    JAWA BARAT                 3205     KABUPATEN GARUT
#
#    pengeluaran_per_kapita                   satuan  tahun
# 0                 8951.96  RIBU RUPIAH/ORANG/TAHUN   2010
# 1                 7658.57  RIBU RUPIAH/ORANG/TAHUN   2010
# 2                 6430.92  RIBU RUPIAH/ORANG/TAHUN   2010
# 3                 8740.07  RIBU RUPIAH/ORANG/TAHUN   2010
# 4                 6149.57  RIBU RUPIAH/ORANG/TAHUN   2010

# %%
# STEP 6: Mengubah kolom 'pengeluaran_per_kapita' dan 'tahun' menjadi numerik
# Hal ini penting agar kita bisa melakukan operasi matematika seperti rata-rata, agregasi, dll.
# errors='coerce' akan mengubah nilai yang tidak bisa dikonversi jadi NaN (supaya tidak error)

df["pengeluaran_per_kapita"] = pd.to_numeric(df["pengeluaran_per_kapita"], errors="coerce")
df["tahun"] = pd.to_numeric(df["tahun"], errors="coerce")

# %%
# STEP 7: Prompt model IBM Granite untuk menganalisis data

prompt = """
Analisis dataset pengeluaran per kapita berikut ini.
Berikan insight, tren, dan rekomendasi kebijakan publik berdasarkan data.
Tuliskan hasil analisis secara ringkas dan jelas.
"""

# Jalankan prompt ke model
hasil_analisis = llm.invoke(prompt)

# Tampilkan hasil analisis
print(hasil_analisis)
# Out:
# Berdasarkan dataset pengeluaran per kapita, dapat disimpulkan beberapa insight dan tren yang berdampak pada kebijakan publik. Berikut adalah analisis ringkas dan jelas:
#
# 1. **Insight**: Pengeluaran per kapita bervariasi tergantung pada kategori biaya, seperti pendidikan, kesehatan, transportasi, dan hiburan. Ada kategori yang menunjukkan pengeluaran yang lebih tinggi, seperti kesehatan, yang mungkin menunjukkan kebutuhan masyarakat untuk layanan kesehatan yang lebih baik.
#
# 2. **Tren**: Data mungkin menunjukkan tren yang berbeda di antara wilayah urban dan rural. Pengeluaran per kapita di wilayah urban lebih tinggi, yang mungkin disebabkan oleh tingginya harga tinggi dan jumlah penduduk yang lebih banyak. Selain itu, tren mungkin menunjukkan pengeluaran yang meningkat pada kategori hiburan dan rekreasi, yang mungkin merupakan indikator perubahan kebiasaan masyarakat.
#
# 3. **Rekomendasi Kebijakan Publik**:
# ...

# %%
# ============================================================
# 📌 INSIGHT AI — VALIDASI DENGAN DATA ASLI
#
# Berdasarkan dataset pengeluaran per kapita, dapat disimpulkan beberapa insight dan tren yang berdampak pada kebijakan publik.
# Berikut adalah analisis ringkas dan jelas:
#
# 1. Insight:
#    Pengeluaran per kapita bervariasi tergantung pada kategori biaya, seperti pendidikan, kesehatan, transportasi, dan hiburan.
#    Ada kategori yang menunjukkan pengeluaran yang lebih tinggi, seperti kesehatan, yang mungkin menunjukkan kebutuhan masyarakat untuk layanan kesehatan yang lebih baik.
#
# 2. Tren:
#    Data mungkin menunjukkan tren yang berbeda di antara wilayah urban dan rural.
#    Pengeluaran per kapita di wilayah urban lebih tinggi, yang mungkin disebabkan oleh tingginya harga dan jumlah penduduk yang lebih banyak.
#    Selain itu, tren mungkin menunjukkan pengeluaran yang meningkat pada kategori hiburan dan rekreasi, yang mungkin merupakan indikator perubahan kebiasaan masyarakat.
#
# 3. Rekomendasi Kebijakan Publik:
#    - Pendidikan: Pemerintah dapat meningkatkan investasi dalam infrastruktur pendidikan, mengurangi biaya pendidikan tinggi, atau meningkatkan kualitas pendidikan di daerah-daerah dengan pengeluaran per kapita yang rendah.
#    - Kesehatan: Pemerintah harus mendorong pengembangan sistem kesehatan yang lebih lancar, memastikan akses ke layanan kesehatan bagi seluruh masyarakat, dan menekankan pencegahan penyakit.
#    - Infrastruktur: Untuk mengurangi disparitas pengeluaran di wilayah urban dan rural, pemerintah perlu meningkatkan infrastruktur dasar di daerah tertinggal.
# ============================================================
